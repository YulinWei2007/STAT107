# %% [markdown]
# # Welcome to Lab: Similarity 🧍🧍‍♂️🧍‍♀️
#
# Many of you already know your group members in this class. However, have you ever wondered if there is someone **even more similar** to you than the people you already know?
#
# In this lab, we'll once again explore the dataset from the **Hello Survey** you've completed, utilizing some new Python skills to calculate your similarity to your peers!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab TA, your CAs, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Kunlun"
ca1_name = "Emily"
ca2_name = "Caroline"
ca3_name = ""


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!

# QOTD to ask your group: What's your favorite (or least favorite) building on campus? 
partner1_name = "Xinmeng Zhang"
partner1_netid = "xinmeng8"
partner1_favbuilding = "Illini Tower"

partner2_name = "Miguel Jaojoco"
partner1_netid = "jaojoco2"
partner2_favbuilding = "Main Quad"

partner3_name = ""
partner3_netid = ""
partner3_favbuilding = ""

# Which lab section are you in? Record it below! It should start with a Y and have 
# 2 numbers after the Y. If you're unsure - ask your TA/CAs!
lab_section = "Y27"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello, Again

# %% [markdown]
# ## Load the Hello Dataset
# To find the people most similar to you in this course, we're going to need the Hello Dataset again.
#
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa25.csv
# ```
#
# Use Python to load this dataset into a DataFrame `df`:

# %%
import pandas as pd
df=pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa25.csv")
df
# Out:
#              Name              Lab When flipping a coin, heads or tails?  \
# 0      Prof. Wade              AL1                                 Heads
# 1     Prof. Karle              AL1                                 Heads
# 2        Muhammad              Y20                                 Heads
# 3            Jake              Y10                                 Heads
# 4         Shourya              Y04                                 Tails
# ...           ...              ...                                   ...
# 1195        arnav              Y31                                 Heads
# 1196      Lorenzo              Y11                                 Heads
# 1197      CA Emma              Y20                                 Tails
# 1198      CA Soph  Y01 Y14 Y15 Y18                                 Heads
# 1199          Jay              Y07                                 Tails
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 1                                             Chocolate
# 2                                             Chocolate
# 3                                             Chocolate
# 4                                             Chocolate
# ...                                                 ...
# 1195                                            Vanilla
# 1196                                          Chocolate
# 1197                                          Chocolate
# 1198                                            Vanilla
# 1199                                            Vanilla
#
#      Do you like morning or night? Is your favorite number even or odd?  \
# 0                            Night                                  Odd
# 1                            Night                                 Even
# 2                            Night                                 Even
# 3                            Night                                  Odd
# 4                            Night                                  Odd
# ...                            ...                                  ...
# 1195                         Night                                  Odd
# 1196                       Morning                                 Even
# 1197                         Night                                  Odd
# 1198                         Night                                  Odd
# 1199                         Night                                  Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                   Yes                          Winter
# 1                   Yes                          Summer
# 2                   Yes                          Summer
# 3                   Yes                          Summer
# 4                    No                          Summer
# ...                 ...                             ...
# 1195                Yes                          Winter
# 1196                Yes                          Summer
# 1197                 No                          Summer
# 1198                Yes                          Winter
# 1199                Yes                          Summer
#
#      Are you in the Gies College of Business?  \
# 0                                 Not in Gies
# 1                                 Not in Gies
# 2                                 Not in Gies
# 3                 In Gies College of Business
# 4                                 Not in Gies
# ...                                       ...
# 1195                              Not in Gies
# 1196              In Gies College of Business
# 1197                              Not in Gies
# 1198                              Not in Gies
# 1199              In Gies College of Business
#
#      Do you prefer Movies or TV shows?  ...  \
# 0                             TV Shows  ...
# 1                               Movies  ...
# 2                               Movies  ...
# 3                             TV Shows  ...
# 4                             TV Shows  ...
# ...                                ...  ...
# 1195                            Movies  ...
# 1196                            Movies  ...
# 1197                            Movies  ...
# 1198                          TV Shows  ...
# 1199                          TV Shows  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                               Sweeden
# 1                                              Maldives
# 2                                              Malaysia
# 3                                                Norway
# 4                                                   UAE
# ...                                                 ...
# 1195                                          Singapore
# 1196                                             Canada
# 1197                                            Sweden
# 1198                                             Mexico
# 1199                                              Paris
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                          Purple                           Nerding Out
# 1                            pink                        with people!!!
# 2                           Green                              Sleeping
# 3                          Yellow                 Hang Out With Friends
# 4                             Red                               Youtube
# ...                           ...                                   ...
# 1195                         Blue                 Hang out with friends
# 1196                         blue                                 sleep
# 1197                        Green                            Crocheting
# 1198                          Red                              Relaxing
# 1199                         Blue                             On Tiktok
#
#      What genre of music do you like the most?  \
# 0                                      Pop EDM
# 1                                          pop
# 2                                      Hip hop
# 3                                  Indie Music
# 4                                    Indie pop
# ...                                        ...
# 1195                                       R&b
# 1196                                      jazz
# 1197                                       Pop
# 1198                                  Hyperpop
# 1199                                       R&B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 Eagle
# 1                                                 sloth
# 2                                                 Husky
# 3                                                 Llama
# 4                                                  Wolf
# ...                                                 ...
# 1195                                               Lion
# 1196                                                dog
# 1197                                               Frog
# 1198                                             Rabbit
# 1199                                               Wolf
#
#      What do you think is the hardest major at UIUC?  \
# 0                                            Physics
# 1                                   computer science
# 2                             Electrical Engineering
# 3                            Electrical Engineering
# 4                                       Astrophysics
# ...                                              ...
# 1195                           Chemical engineering
# 1196                                              cs
# 1197                                Computer Science
# 1198                          Aerospace Engineering
# 1199                                          Chem E
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 1                          Taylor Swift
# 2                            Kanye West
# 3                           Tame Impala
# 4                  Cigarettes after sex
# ...                                 ...
# 1195                                NaN
# 1196                                MBY
# 1197                          Lady Gaga
# 1198                     Ayesha Erotica
# 1199                        Mac Demarco
#
#      What's your favorite social media app?  \
# 0                                   YouTube
# 1                                 instagram
# 2                                 Instagram
# 3                                 Instagram
# 4                                 Instagram
# ...                                     ...
# 1195                              Instagram
# 1196                                 wechat
# 1197                                 TikTok
# 1198                              Pinterest
# 1199                                 TikTok
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                              Factorio
# 1                                                 cards
# 2                                             Minecraft
# 3                                            Volleyball
# 4                                                   Spy
# ...                                                 ...
# 1195                                                NaN
# 1196                                                 MC
# 1197                                          Minecraft
# 1198                                            Twister
# 1199                                         Basketball
#
#      Where is your dream vacation spot?
# 0                        Mountain Cabin
# 1                              Maldives
# 2                           Switzerland
# 3                      Switzerland Alps
# 4                               Iceland
# ...                                 ...
# 1195                          Indonesia
# 1196                             Canada
# 1197                              Italy
# 1198                        Mexico City
# 1199                             Hawaii
#
# [1200 rows x 160 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("df" in vars()), "This is not the Hello Dataset you're looking for. Check the URL."
assert("Where is your dream vacation spot?" in df), "This is not the Hello Dataset you're looking for. Check the URL."
assert(len(df) >= 1140), "This is not the Hello Dataset you're looking for. Check the URL."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Finding Yourself
# Before finding people you are **similar to**, you have to find **yourself** - literally!
#
# ### Puzzle 1.1: Your Row
# In the following cell, write the Python code to create a **new** DataFrame with only yourself, named `df_me`, and then display it.
#
# *Note: if you cannot find yourself in the Hello Dataset, try adding a space after your name within the string. If you did not fill out the Hello Survey, pick one of your TAs, CAs, or Professor Karle or Wade! Their names are in the survey in the format of "TA Alex" or "Prof. Karle".*

# %%
df_me = df[df["Name"] == "yes！"]
df_me
# Out:
#      Name  Lab When flipping a coin, heads or tails?  \
# 485  yes！  Y27                                 Heads
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 485                                          Chocolate
#
#     Do you like morning or night? Is your favorite number even or odd?  \
# 485                       Morning                                 Even
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 485                Yes                          Winter
#
#     Are you in the Gies College of Business?  \
# 485                              Not in Gies
#
#     Do you prefer Movies or TV shows?  ...  \
# 485                          TV Shows  ...
#
#     Besides the US, what country would you like to live in?  \
# 485                                              China
#
#     What is your favorite color? Favorite way to spend your free time?  \
# 485                         gray                      play mobile game
#
#     What genre of music do you like the most?  \
# 485                                      Jazz
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 485                                              Panda
#
#     What do you think is the hardest major at UIUC?  \
# 485                                         Math+CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 485                        My roommate                                 WeChat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 485                                      Honor of King
#
#     Where is your dream vacation spot?
# 485                        New zealand
#
# [1 rows x 160 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.1 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("df_me" in vars()), "Make sure you named the DataFrame with just you `df_me`."
assert("Where is your dream vacation spot?" in df_me), "Your `df_me` should have the same columns as our `df`."
assert(len(df_me.columns.to_list()) == 160), "Your `df_me` should have the same number of columns as our original `df`."
assert(len(df_me) == 1), "Your `df_me` should only have one row: yourself."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## DataFrame vs. Series
#
# In `pandas`, we have worked with **DataFrames** all semester long! DataFrames are similar to excel sheets and have rows and columns with data!
#
# Another data type is called a **Series**.
#
# - A **Series** is a single row with zero or more values (columns). You can think of a DataFrame as a collection of **Series** objects. When we deal with a single row, we will usually want to deal with a **Series** instead of a **one row DataFrame**
#
# In this lab, we will learn how to convert from a **one row DataFrame** to a **Series**, but here's a quick rundown on how to convert from types:

# %% [markdown]
# ### Converting Types
#
# The `pandas` library makes it easy to convert between a **Series** and a **DataFrame**.
#
# - From a **Series** (`row`) to a **DataFrame**:
#     - `row.to_frame()`
# - From a **DataFrame** (`df`) to a **Series**:
#     - `df.iloc[0]`, if the DataFrame has one row
#
# See this guide, https://discovery.cs.illinois.edu/guides/DataFrame-Fundamentals/dataframe-loc-vs-iloc/, for more information about `iloc[]`.

# %% [markdown]
# ### Puzzle 1.2: Transform your row into a Series
# Using the correct function from above, **transform** the `df_me` row containing only you from a **one-row DataFrame** into a **Series**.
#
# Make sure the Series is named `my_row` (this will match up with code we provide you with later):

# %%
my_row = df_me.iloc[0]
my_row
# Out:
# Name                                                                       yes！
# Lab                                                                         Y27
# When flipping a coin, heads or tails?                                     Heads
# Is your favorite ice cream flavor chocolate or vanilla?               Chocolate
# Do you like morning or night?                                           Morning
#                                                                       ...
# What do you think is the hardest major at UIUC?                         Math+CS
# Who is your favorite music artist?                                  My roommate
# What's your favorite social media app?                                   WeChat
# What is your favorite game to play (either video game or IRL)?    Honor of King
# Where is your dream vacation spot?                                  New zealand
# Name: 485, Length: 160, dtype: object

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('my_row' in vars()), "Your series should be named `my_row`."
assert(type(my_row) == pd.core.series.Series), "Make sure you've correctly converted your one-row DataFrame into a Series..."
assert(my_row.to_frame().T.equals(pd.DataFrame(df_me, dtype = 'O'))), "Make sure my_row corresponds to your row in df"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Choosing Your Columns

# %% [markdown]
# Before we begin, we have to think about our approach to finding your DISCOVERY twin.
#
# You may have noticed our Hello Dataset has **more than 100 questions**. Instead of finding the most similar person to you using **every question**, we'll pick out a few questions to analyze that we think will do the best job at finding your twin!
#
# **But first, we need to revisit the questions.**
#
# Recall the function `df.columns.tolist()`. To recap, this command will list **all of the columns** (in this case, our questions) in a DataFrame.
#
# Use `df.columns.tolist()` in the cell below.
#
# <br>
#
# **Viewing the Full Output**: When you do that, you will likely see the message:
#
# > Output exceeds the __size limit__. Open the full output data __in a text editor__.
#
# If you do, click the **in a text editor** link to open the whole list in a new tab of VSCode.

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Lab',
#  'When flipping a coin, heads or tails?',
#  'Is your favorite ice cream flavor chocolate or vanilla?',
#  'Do you like morning or night?',
#  'Is your favorite number even or odd?',
#  'Do you have a pet?',
#  'Do you prefer summer or winter?',
#  'Are you in the Gies College of Business?',
#  'Do you prefer Movies or TV shows?',
#  'Do you prefer pizza or hamburgers?',
#  'You describe yourself as:',
#  'Do you prefer sweet or salty food?',
#  'Do you eat breakfast?',
#  'Do you speak a second language?',
#  'Do you prefer cats or dogs?',
#  'Do you prefer Italian or Mexican food?',
#  'Cookies or Brownies?',
#  'Do you like apples or bananas?',
#  'Waffles or pancakes?',
#  'Night Owl or Early Bird?',
#  'Did you do high school in Illinois?',
#  'Do you typically shower in the morning or at night?',
#  'Do you prefer sweet or savory food?',
#  'What month is your birthday?',
#  'Do you use a Mac or Windows Laptop?',
#  'Do you like pizza or pasta?',
#  'Do you wear glasses?',
#  'Fall or spring season?',
#  'Do you prefer pink or blue?',
#  'Does your UIN end with an even or odd number?',
#  'Do you use corrective lenses (contacts/glasses)?',
#  'Do you prefer Apple Music or Spotify?',
#  'Do you have any siblings?',
#  'Are you from Chicago?',
#  'Pick a number: One or Two.',
#  'Do you prefer basketball or football?',
#  'Do you prefer the beach or mountains?',
#  'Do you prefer breakfast or dinner?',
#  'Do you prefer Coca Cola or Pepsi?',
#  'Do you prefer coffee or tea?',
#  'Are you an extrovert or introvert?',
#  'Do you prefer hotdogs or hamburgers?',
#  'Do you like Messi or Ronaldo?',
#  'Have you ever been outside of United States?',
#  'Do you have more than 1 sibling?',
#  'Does pineapple belong on pizza?',
#  'Do you live in Urbana or Champaign?',
#  'Do you prefer sunny or rainy days?',
#  'Red or Blue?',
#  'Is your DISCOVERY lab the last class of your day?',
#  'Have you had your 19th birthday?',
#  'Are you a Statistics Major?',
#  'Are you currently wearing shorts?',
#  'Are you from Chicago or the suburbs?',
#  'Are you registered for the 9am or 11am lecture?',
#  'Are you team Edward or team Jacob?',
#  'Cold Coffee or Hot Coffee?',
#  'Did you go to the football game against WIU?',
#  'Cookies or Ice Cream?',
#  'Do you prefer urban or rural areas?',
#  'Do you prefer creamy or chunky peanut butter?',
#  'Dunkin or Starbucks?',
#  'Football or soccer?',
#  'Fruits or vegetables?',
#  'Do you prefer gold or silver jewelry?',
#  'Do you prefer hot or cold weather?',
#  'Do you prefer in person or online classes?',
#  'Do you prefer Instagram Reels or TikTok?',
#  'Do you prefer Kendrick Lamar or Drake?',
#  'Do you prefer ketchup or honey mustard?',
#  'Do you prefer Lebron James or Michael Jordan?',
#  'Do you eat beef?',
#  'Do you exercise regularly?',
#  'Do you game on a PC or Console?',
#  'Do you have a brother?',
#  'Do you prefer being hot or cold?',
#  'Do you like chocolate ice cream?',
#  'Do you like cilantro or not?',
#  'Do you prefer DC or Marvel?',
#  'Do you like ice cream?',
#  'Do you like Mint Chocolate Chip ice cream?',
#  'Do you like pizza?',
#  'Red or Green?',
#  'Do you like running?',
#  'Do you like school?',
#  'Sweet food or spicy food?',
#  'Do you live in a dorm or apartment?',
#  'Do you live in University Housing or Private Housing?',
#  'Do you prefer Xbox or Playstation?',
#  'Do you prefer travelling by plane or cruise?',
#  'Breakfast or Lunch?',
#  'Do you prefer lunch or dinner?',
#  'Do you prefer mild or spicy food?',
#  'Nike or Adidas?',
#  'Do you prefer pens or pencils?',
#  'Purple or orange?',
#  'Red or Black?',
#  'Sausage or Bacon?',
#  'Skittles or M&Ms?',
#  'Soup or Salad?',
#  'Chicken or steak?',
#  'Tacos or Burritos?',
#  'Do you prefer the window or aisle seat on an airplane?',
#  'TikTok or Instagram?',
#  'Do you prefer to work remotely or in office?',
#  'What comes first, milk or cereal?',
#  'Do to typically go to bed before or after 11pm?',
#  'How should toilet paper be rolled?',
#  'Have you eaten lunch today?',
#  'Headphones or Earbuds?',
#  'If you had to go to sleep at the same time every night, would it be ...',
#  'Is a hot dog a sandwich?',
#  'Is a tomato a fruit or a vegetable?',
#  'Is Apple better than Android?',
#  'Is Tuesday or Wednesday better?',
#  'Is your birth date odd or even?',
#  'Is your birth MONTH even or odd?',
#  'Is your birthday in the first fifteen days of the month?',
#  'Matcha or Coffee?',
#  'Hoodie + Shorts or Shirt + Pants?',
#  'Noodles or Rice?',
#  'Savory or sweet breakfast?',
#  'Was Illinois Your Dream School?',
#  'Sights and Sounds: Were you Orange or Blue?',
#  'Seals or Penguins?',
#  'Orange or Blue?',
#  'Soda or Juice?',
#  'North Pole or South Pole?',
#  'Prefer Lecture of Lab in DISCOVERY?',
#  'Computer Science or Statistics?',
#  'Do you prefer Mom or Dad?',
#  'Would you rather be Courageous Pizza or Honest Broccoli?',
#  'Would you rather be too hot or too cold?',
#  'When do you go to the gym?',
#  'Orange or Apple?',
#  "Would you rather know how you die or know when you'd die?",
#  'Which of the following descriptions best matches your favorite movie?',
#  'Is math red or blue?',
#  'Do you get closer to 6 or 7 hours of sleep?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a night?',
#  'How many siblings do you have?',
#  'Pick a number between 1 and 10.',
#  'What is your shoe size (US size)?',
#  'How many cups (8 oz.) of water do you drink a day?',
#  'What number do you consider as an unlucky number?',
#  'How many people is the ideal number of people at a party?',
#  'What is your phone battery percentage currently at?',
#  'Besides the US, what country would you like to live in?',
#  'What is your favorite color?',
#  'Favorite way to spend your free time?',
#  'What genre of music do you like the most?',
#  'If you were an animal, which would you be? / What is your spirit animal?',
#  'What do you think is the hardest major at UIUC?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'What is your favorite game to play (either video game or IRL)?',
#  'Where is your dream vacation spot?']

# %% [markdown]
# ### Puzzle 1.3: Choosing Your Columns
# From the above list of **columns** (questions), choose **at least 12 questions** to work with moving forward. Please use **only questions with binary answers** for this part of the analysis :)
#
# ***Make sure to choose the questions intentionally! You'll want to pick questions you find interesting and questions that you think would best measure the similarity between 2 people (don't just pick the first 12 questions).***
#
# These will be the questions used to **calculate your similarity** to other people in DISCOVERY! Feel free to include more if you'd like.
#
# Store them as a **list** of **strings** named `questions` in the Python cell below:

# %%
questions = [
    "When flipping a coin, heads or tails?",
    "Is your favorite ice cream flavor chocolate or vanilla?",
    "Do you like morning or night?",
    "Is your favorite number even or odd?", 
    "Do you have a pet?",
    "Do you prefer summer or winter?",
    "Do you prefer Movies or TV shows?",
    "Do you prefer pizza or hamburgers?",
    "Do you prefer sweet or salty food?",
    "Do you speak a second language?",
    "Do you prefer cats or dogs?",
    "Do you prefer Italian or Mexican food?",
    "Cookies or Brownies?",
    "Do you like apples or bananas?",
    "Waffles or pancakes?",
    "Night Owl or Early Bird?",
    "Do you typically shower in the morning or at night?"]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.3 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('questions' in vars()), "Please name your list of questions `questions`."
assert(type(questions) == list and type(questions[0]) == str), "Make sure your `questions` variable is a list of strings."
assert(len(questions) >= 12), "Do you have at least 12 questions in your columns list?"
for q in questions:
   assert(q in df), f"\"{q}\" not in columns of `df`. Double check that you've copied each question correctly. The question texts should match up EXACTLY with the output from `df.columns.to_list()`."
for q in questions:
   assert(len(df[q].value_counts()) == 2), "Make sure that you've only included questions with binary answers in your columns list."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: The Similarity Function

# %% [markdown]
# Now that we have chosen the **questions** we'd like to evaluate, it's time to create a **function** to calculate a similarity value for each person, or each row in `df`.
#
# In lecture, you learned that a Python **function** takes an **input** in and **returns** a **value**.
#
# For this specific function, we will take a **row** and calculate a **similarity score** for that row.
#
# But first, **print your list of questions** using the Python cell below for reference:

# %%
print(questions)
# Out:
# ['When flipping a coin, heads or tails?', 'Is your favorite ice cream flavor chocolate or vanilla?', 'Do you like morning or night?', 'Is your favorite number even or odd?', 'Do you have a pet?', 'Do you prefer summer or winter?', 'Do you prefer Movies or TV shows?', 'Do you prefer pizza or hamburgers?', 'Do you prefer sweet or salty food?', 'Do you speak a second language?', 'Do you prefer cats or dogs?', 'Do you prefer Italian or Mexican food?', 'Cookies or Brownies?', 'Do you like apples or bananas?', 'Waffles or pancakes?', 'Night Owl or Early Bird?', 'Do you typically shower in the morning or at night?']

# %% [markdown]
# ### Puzzle 2.1: The Similarity Function
#
# In the code below, you will find an outline for a `similarity` function that returns a similarity score:
#
# > ```py
# > def similarity(row):
# >     # This function will keep track of a `score` of how similar two rows are with each other.
# >     # The score begins at zero and we will add to it every time a row matches.
# >     score = 0
# >
# >     # This if statement below checks to see if the `row` shares your choice between Coffee and Tea
# >     # - If the values are the same (==), we add one to the score.
# >     # - If the values are NOT the same, the `score = score + 1` line is skipped.
# >     if row["Coffee or Tea?"] == my_row["Coffee or Tea?"]:
# >         score = score + 1
# >
# >     # Finally, return the `score`.
# >     # ...this line (the return statement) should always be the LAST line.
# >     return score
# > ```
#
# Using this same function structure, complete your `similarity` function below **using the questions you picked out earlier**.  This will require you to write **one if statement** for each question you selected:

# %%
def similarity(row):
    # Your Task Here:
    # Repeat the above syntax many times for EACH question (column) that you have chosen in your list
    # IMPORTANT: Make sure to keep your lines all at this same level of tabbing out from the start.    
    # ALSO IMPORTANT: Delete or the replace the "Coffee or Tea?" question!
    #                 (unless you've decided that is one of your evaluating questions). 
    
    score = (row[questions] == my_row[questions]).sum()


    ...

    return score

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 2.1 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(similarity(my_row) == len(questions) or similarity(my_row) == my_row[questions].count()), "Ensure you've added all the questions from your list and ONLY questions from your list correctly to your similarity function."
assert( len(df.apply(similarity, axis = 1).unique()) > 2 ), "Your function must return differnet values for differnet rows."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.2: Applying the Similarity Function
# Now that you've properly defined the similarity function, we need to **apply** it to the rest of the Hello Dataset DataFrame so we can produce a **similarity score** for each person who took the survey!
#
# Using the above explanation as reference, **add a column** named `Similarity Score` to your original DataFrame that contains the value after running your similarity function you defined earlier across all rows:
#
# (Hint): Look back to `lab_illini` part 2.2 & `lab_gpa` part 1.1

# %%
df["Similarity Score"] = df.apply(similarity, axis=1)

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 2.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('Similarity Score' in df), "Make sure you've named and added the Similarity Score column to your original df."
assert(df['Similarity Score'].dtype == 'int64'), "Double check that you've called the similarity function correctly in your df.apply()."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Finding your Twin(s)

# %% [markdown]
# Your last column `Similarity Score` in `df` is now a metric (a measurement) of how **similar** you are to everyone else in the class, based on the **questions you've chosen**!
#
# Finally, we can do analytical Data Science!

# %% [markdown]
# ### Puzzle 3.1: Your Twin in 107
#
# Using the Python cell below, find the **person most similar to you in the entire course**. Think about how you would do this using the `Similarity Score` column.
#
# Note that **you should be most similar to yourself** (you will always match yourself)! This is not the right answer. Find the person with the highest score ***aside from yourself***. *(There is a chance there can be multiple people tied as the person most similar to you and that's okay!)*
#
# Make sure to display the rows.

# %%
tiwn =df.nlargest(5, 'Similarity Score')
tiwn
# Out:
#        Name  Lab When flipping a coin, heads or tails?  \
# 485    yes！  Y27                                 Heads
# 28   Sophia  Y26                                 Heads
# 340   Mayte  Y31                                 Heads
# 24   Amanda  Y29                                 Heads
# 121   Chang  Y35                                 Heads
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 485                                          Chocolate
# 28                                           Chocolate
# 340                                          Chocolate
# 24                                           Chocolate
# 121                                          Chocolate
#
#     Do you like morning or night? Is your favorite number even or odd?  \
# 485                       Morning                                 Even
# 28                        Morning                                  Odd
# 340                         Night                                 Even
# 24                          Night                                  Odd
# 121                         Night                                 Even
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 485                Yes                          Winter
# 28                 Yes                          Winter
# 340                Yes                          Winter
# 24                 Yes                          Winter
# 121                Yes                          Winter
#
#     Are you in the Gies College of Business?  \
# 485                              Not in Gies
# 28                               Not in Gies
# 340                              Not in Gies
# 24               In Gies College of Business
# 121                              Not in Gies
#
#     Do you prefer Movies or TV shows?  ... What is your favorite color?  \
# 485                          TV Shows  ...                         gray
# 28                             Movies  ...                       Yellow
# 340                          TV Shows  ...                         Blue
# 24                           TV Shows  ...                        Black
# 121                            Movies  ...                        black
#
#     Favorite way to spend your free time?  \
# 485                      play mobile game
# 28                                Reading
# 340    with family/friends or working out
# 24                              On tiktok
# 121                            play games
#
#     What genre of music do you like the most?  \
# 485                                      Jazz
# 28                                     2000’s
# 340                    Music of Latin America
# 24                                        Pop
# 121                                    minyao
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 485                                              Panda
# 28                                         Whale shark
# 340                                    a golden doodle
# 24                                               Panda
# 121                                             lizard
#
#     What do you think is the hardest major at UIUC?  \
# 485                                         Math+CS
# 28                                 Computer Science
# 340                                     Engineering
# 24                        Bio chemical engineering
# 121                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 485                        My roommate                                 WeChat
# 28                          Billy Joel                              Instagram
# 340                              Drake                                 Tiktok
# 24                        $uicide boy$                                 Tiktok
# 121                            zhaolei                                 Wechat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 485                                      Honor of King
# 28                                             Mahjong
# 340                                         Mario Kart
# 24                                            Puzzles
# 121                                                DBD
#
#     Where is your dream vacation spot? Similarity Score
# 485                        New zealand               17
# 28                           Santorini               15
# 340                             Hawaii               15
# 24                               Haiti               14
# 121                                 US               14
#
# [5 rows x 161 columns]

# %% [markdown]
# ### Puzzle 3.2: Your Lab Twin
#
# Now, chances are your twin isn't in your lab section. Because we conveniently have our row, `Similarity Score` applied to the **entire** set of responses to the survey, we can create smaller DataFrames to answer more questions.
#
# We want to find the person most similar to you in **your lab section**, otherwise known as your lab twin! We can create a new DataFrame to answer this question.
#
# However, some of your CAs and TAs, who are part of your lab section, are in more than one lab section! Those who have multiple sections have `Y##, Y##...` in their Sections column. How can we create a DataFrame that includes the CAs and TAs who are in more than one lab section? Python saves the day again.
#
# #### **The `contains` Function**
# In Python, the `contains` function can be used to check if a specific **substring** is present in a **string**.
#
# This will come in handy for us, because we can see if `Y##` is in the **names** of any rows in our DataFrame.
#
# Using the `contains` function, create a **new DataFrame** with everyone in your lab section: `df_section`. Part of the statement has been completed for you to show you how to use `contains`. Complete it and make sure to display the dataframe.
#
# *Note that we have to cast our `Lab` column of `df` to a **string** by using `.str`.
#
# *Second note: the `na=False` parameter in the `contains` function makes it so that we ignore the rows with no lab section.

# %%
df_section = df[(df['Lab'].str.contains("Y27",na=False))]
df_section
# Out:
#               Name       Lab When flipping a coin, heads or tails?  \
# 14           Swara       Y27                                 Heads
# 30           Katie       Y27                                 Heads
# 193            Nao       Y27                                 Tails
# 219          Darsh       Y27                                 Tails
# 226          Arnav       Y27                                 Heads
# 271         Andrew       Y27                                 Tails
# 275         Miguel       Y27                                 Heads
# 327           Nate       Y27                                 Tails
# 341           Ryan       Y27                                 Tails
# 361         Elisha       Y27                                 Tails
# 363           Mino       Y27                                 Tails
# 453        Prateek       Y27                                 Heads
# 485           yes！       Y27                                 Heads
# 527         Payton       Y27                                 Tails
# 537          Osama       Y27                                 Heads
# 557          Berra       Y27                                 Heads
# 584   Vikramaditya       Y27                                 Heads
# 586          Daryl       Y27                                 Tails
# 607         Nirmit       Y27                                 Heads
# 615           Alex       Y27                                 Heads
# 632        Syafino       Y27                                 Heads
# 670       Yashfeen       Y27                                 Heads
# 770            Ady       Y27                                 Heads
# 821            Ari       Y27                                 Heads
# 861            Joy       Y27                                 Tails
# 940           Tian       Y27                                 Heads
# 956          Kenny       Y27                                 Heads
# 973          David       Y27                                 Heads
# 1096      CA Emily  Y22, Y27                                 Heads
# 1107   CA Caroline   Y07 Y27                                 Heads
# 1156        Winona       Y27                                 Heads
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 14                                              Vanilla
# 30                                            Chocolate
# 193                                           Chocolate
# 219                                             Vanilla
# 226                                           Chocolate
# 271                                             Vanilla
# 275                                             Vanilla
# 327                                           Chocolate
# 341                                             Vanilla
# 361                                           Chocolate
# 363                                           Chocolate
# 453                                             Vanilla
# 485                                           Chocolate
# 527                                           Chocolate
# 537                                                 NaN
# 557                                           Chocolate
# 584                                           Chocolate
# 586                                           Chocolate
# 607                                             Vanilla
# 615                                           Chocolate
# 632                                             Vanilla
# 670                                             Vanilla
# 770                                             Vanilla
# 821                                           Chocolate
# 861                                           Chocolate
# 940                                           Chocolate
# 956                                           Chocolate
# 973                                           Chocolate
# 1096                                          Chocolate
# 1107                                            Vanilla
# 1156                                          Chocolate
#
#      Do you like morning or night? Is your favorite number even or odd?  \
# 14                           Night                                  Odd
# 30                         Morning                                  Odd
# 193                          Night                                 Even
# 219                          Night                                  Odd
# 226                          Night                                  Odd
# 271                        Morning                                  Odd
# 275                          Night                                 Even
# 327                          Night                                  Odd
# 341                          Night                                 Even
# 361                        Morning                                  Odd
# 363                          Night                                  Odd
# 453                          Night                                  Odd
# 485                        Morning                                 Even
# 527                          Night                                  Odd
# 537                          Night                                  Odd
# 557                          Night                                 Even
# 584                          Night                                  Odd
# 586                          Night                                  Odd
# 607                          Night                                 Even
# 615                          Night                                 Even
# 632                        Morning                                 Even
# 670                          Night                                  Odd
# 770                        Morning                                 Even
# 821                        Morning                                  Odd
# 861                          Night                                 Even
# 940                        Morning                                  Odd
# 956                        Morning                                 Even
# 973                          Night                                 Even
# 1096                         Night                                 Even
# 1107                         Night                                  Odd
# 1156                         Night                                 Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 14                   No                          Winter
# 30                  Yes                          Summer
# 193                 Yes                          Winter
# 219                  No                          Summer
# 226                  No                          Summer
# 271                 Yes                          Summer
# 275                  No                          Summer
# 327                 Yes                          Summer
# 341                  No                          Summer
# 361                 Yes                          Winter
# 363                  No                          Summer
# 453                  No                          Winter
# 485                 Yes                          Winter
# 527                 Yes                          Summer
# 537                  No                          Summer
# 557                  No                          Summer
# 584                  No                          Summer
# 586                  No                          Summer
# 607                 Yes                          Summer
# 615                  No                          Summer
# 632                 Yes                          Winter
# 670                  No                          Summer
# 770                 Yes                          Summer
# 821                  No                          Winter
# 861                  No                          Winter
# 940                  No                          Summer
# 956                  No                          Summer
# 973                  No                          Summer
# 1096                Yes                          Winter
# 1107                 No                          Summer
# 1156                Yes                          Winter
#
#      Are you in the Gies College of Business?  \
# 14                                Not in Gies
# 30                In Gies College of Business
# 193                               Not in Gies
# 219                               Not in Gies
# 226                               Not in Gies
# 271                               Not in Gies
# 275                               Not in Gies
# 327               In Gies College of Business
# 341                               Not in Gies
# 361                               Not in Gies
# 363                               Not in Gies
# 453                               Not in Gies
# 485                               Not in Gies
# 527                               Not in Gies
# 537               In Gies College of Business
# 557                               Not in Gies
# 584                               Not in Gies
# 586                               Not in Gies
# 607                               Not in Gies
# 615                               Not in Gies
# 632                               Not in Gies
# 670               In Gies College of Business
# 770               In Gies College of Business
# 821                               Not in Gies
# 861               In Gies College of Business
# 940                               Not in Gies
# 956                               Not in Gies
# 973               In Gies College of Business
# 1096                              Not in Gies
# 1107              In Gies College of Business
# 1156              In Gies College of Business
#
#      Do you prefer Movies or TV shows?  ... What is your favorite color?  \
# 14                              Movies  ...                      Purple
# 30                            TV Shows  ...                       Purple
# 193                             Movies  ...                         Pink
# 219                             Movies  ...                         Blue
# 226                             Movies  ...                       Orange
# 271                           TV Shows  ...                         blue
# 275                           TV Shows  ...                        Green
# 327                           TV Shows  ...                        Green
# 341                           TV Shows  ...                        Green
# 361                           TV Shows  ...                       purple
# 363                             Movies  ...                         Blue
# 453                             Movies  ...                        black
# 485                           TV Shows  ...                         gray
# 527                           TV Shows  ...                         Blue
# 537                             Movies  ...                 Black or Red
# 557                           TV Shows  ...                         Blue
# 584                           TV Shows  ...                        Green
# 586                           TV Shows  ...                        Black
# 607                             Movies  ...                         blue
# 615                           TV Shows  ...                         Blue
# 632                           TV Shows  ...                         blue
# 670                           TV Shows  ...                        Pink
# 770                           TV Shows  ...                         Blue
# 821                           TV Shows  ...                         Blue
# 861                             Movies  ...                         blue
# 940                             Movies  ...                         Blue
# 956                             Movies  ...                          Red
# 973                             Movies  ...                        Green
# 1096                            Movies  ...                         pink
# 1107                            Movies  ...                         blue
# 1156                          TV Shows  ...                         blue
#
#      Favorite way to spend your free time?  \
# 14                               Going out
# 30                                Shopping
# 193               hanging out with friends
# 219                  Scroll through Tiktok
# 226                        Watching movies
# 271                        play basketball
# 275                             Volleyball
# 327               Hanging out with friends
# 341                             Basketball
# 361                                rotting
# 363                                Fishing
# 453                            Video Games
# 485                       play mobile game
# 527                               Sleeping
# 537                           Making Money
# 557                           With friends
# 584                                Gooning
# 586                               sleeping
# 607                                    bed
# 615                           With Friends
# 632                                    gym
# 670              Hanging out with friends
# 770               hanging out with friends
# 821                            Working out
# 861                           stay at home
# 940                      Playing basketall
# 956                          Gym or soccer
# 973                                    gym
# 1096                          With friends
# 1107                          With friends
# 1156                          Watch movie
#
#      What genre of music do you like the most?  \
# 14                                        Pop
# 30                                         Pop
# 193                                        rap
# 219                                        Rap
# 226                                        Pop
# 271                                        rap
# 275                                        Pop
# 327                                    Country
# 341                                        Rap
# 361                                       kpop
# 363                           Alternative Rock
# 453                                        Pop
# 485                                       Jazz
# 527                               Alternative
# 537                                 Rap or R&B
# 557                                      Indie
# 584                                        R&B
# 586                                  Afrobeats
# 607                                        rap
# 615                                  Pop Music
# 632                                        pop
# 670                                        Rap
# 770                                    Country
# 821                                  Indie Pop
# 861                              popular music
# 940                                        Pop
# 956                                        Rap
# 973                                     polish
# 1096                                   hip hop
# 1107                                   Country
# 1156                                      pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 14                                              Penguin
# 30                                                  Dog
# 193                                            Meerkat
# 219                                                 Dog
# 226                                            Capybara
# 271                                                 fox
# 275                                                 Owl
# 327                                                 Cow
# 341                                               Lion
# 361                                                 cat
# 363                                    Flathead Catfish
# 453                                                 Dog
# 485                                               Panda
# 527                                             Peacock
# 537                                                Lion
# 557                                           Red Panda
# 584                                                Lion
# 586                                               Tiger
# 607                                             unicorn
# 615                                             Penguin
# 632                                                 cat
# 670                                            Unicorn
# 770                                               otter
# 821                                                Lion
# 861                                                 dog
# 940                                           Panda/yes
# 956                                                 Dog
# 973                                           squierrel
# 1096                                            Cheetah
# 1107                                             Monkey
# 1156                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 14                                       Engineering
# 30                                  Computer Science
# 193                                 Computer Science
# 219                           Electrical engineering
# 226                                            ChemE
# 271                                          premed
# 275                            Computer Engineeriing
# 327                                               CS
# 341                                         Business
# 361                                               CS
# 363                           Electrical Engineering
# 453                           Aerospace Engineeering
# 485                                          Math+CS
# 527                                     Engineering
# 537                     Anything to do with Medicine
# 557                                 Computer Science
# 584                                        Sociology
# 586                                      Engineering
# 607                                               CS
# 615                           Electrical Engineering
# 632                                         comp eng
# 670                                     Engineering
# 770                                        chemistry
# 821                                      Engineering
# 861                                               cs
# 940                                 Computer Science
# 956                                      Grainger CS
# 973                                               cs
# 1096                                             ECE
# 1107                                Computer Science
# 1156                                     engineering
#
#      Who is your favorite music artist?  \
# 14                               Laufey
# 30                          Noah Kahan
# 193                    Childish Gambino
# 219                               Drake
# 226                               Queen
# 271                       daniel caesar
# 275                       Frank Sinatra
# 327                          Luke Combs
# 341                               Drake
# 361                               ARTMS
# 363                           The Verve
# 453                               Drake
# 485                         My roommate
# 527                 Tyler, the Creator
# 537                Nipsey Hussle or Mo3
# 557                        Dominic Fike
# 584                          Beabadobee
# 586                              Davido
# 607                            netspend
# 615                            Jay Chou
# 632                                 idk
# 670                      Billie Eilish
# 770                        Old Dominion
# 821                                 TTC
# 861                        Taylor Swift
# 940                            Jay Chou
# 956                          The Weeknd
# 973                               drake
# 1096                         Noah Kahan
# 1107                 Treaty Oak Revival
# 1156                             laufey
#
#      What's your favorite social media app?  \
# 14                                Instagram
# 30                                   TikTok
# 193                                  TikTok
# 219                                  Tiktok
# 226                                 Twitter
# 271                                  tiktok
# 275                               Instagram
# 327                                  TikTok
# 341                               Instagram
# 361                                 twitter
# 363                                 Youtube
# 453                               instagram
# 485                                  WeChat
# 527                                  TikTok
# 537                         Don't Have one
# 557                                  TikTok
# 584                                  Tiktok
# 586                                  Tiktok
# 607                                  tiktok
# 615                               Instagram
# 632                               instagram
# 670                               Snapchat
# 770                                snapchat
# 821                                  Tiktok
# 861                                red note
# 940                                  Tiktok
# 956                                  Tiktok
# 973                                snapchat
# 1096                              instagram
# 1107                              Instagram
# 1156                              instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 14                                                  Uno
# 30                                                 Clue
# 193                                  stress (card game)
# 219                                        Clash Royale
# 226                                              Soccer
# 271                                          basketball
# 275                                              Roblox
# 327                                        MLB the Show
# 341                                            Fortnite
# 361                                              skyrim
# 363                                 Hill Climb Racing 2
# 453                                             Cricket
# 485                                       Honor of King
# 527                                            Fortnite
# 537                                       Hide and Seek
# 557                                              Roblox
# 584                                              Soccer
# 586                                              Farcry
# 607                                              roblox
# 615                                    Football Manager
# 632                                                csgo
# 670                                          Solitaire
# 770                                         pickleball
# 821                                               Poker
# 861                                   Teamfight Tactics
# 940                                                 CS2
# 956                                  Soccer or Football
# 973                                        clash royale
# 1096                                          minecraft
# 1107                                             Soccer
# 1156                                           nonogram
#
#                      Where is your dream vacation spot? Similarity Score
# 14                                               Greece                6
# 30                                              Croatia               11
# 193                                            Shang hi               10
# 219                                              Monaco                8
# 226                                              Munich                8
# 271                                               japan                8
# 275                                            Maldives                6
# 327                                              Hawaii                8
# 341                                               Japan                9
# 361                                         south korea               14
# 363   Lodge next to a well-stocked lake in the deep ...                7
# 453                                         Switzerland                9
# 485                                         New zealand               17
# 527                                              Canada                9
# 537                                               Mecca                7
# 557                                      Southern Italy                9
# 584                                              Cancun               10
# 586                                             Bahamas                8
# 607                                         Switzerland                8
# 615                                             Beaches                9
# 632                                              greece               11
# 670                                           Maldives                 8
# 770                                              Hawaii               10
# 821                                              Hawaii               11
# 861                                               Japan               10
# 940                                               Beach               10
# 956                                             Bahamas               10
# 973                                              hawaii                9
# 1096                                             Europe               11
# 1107                                              Italy                7
# 1156                                              tokyo               12
#
# [31 rows x 161 columns]

# %% [markdown]
# ### Puzzle 3.3: Your Lab Twin!
#
# Similarly to Puzzle 3.1, find your lab section twin. Make sure to display the dataframe.

# %%
labtwin = df_section.nlargest(20, "Similarity Score")
labtwin
# Out:
#               Name       Lab When flipping a coin, heads or tails?  \
# 485           yes！       Y27                                 Heads
# 361         Elisha       Y27                                 Tails
# 1156        Winona       Y27                                 Heads
# 30           Katie       Y27                                 Heads
# 632        Syafino       Y27                                 Heads
# 821            Ari       Y27                                 Heads
# 1096      CA Emily  Y22, Y27                                 Heads
# 193            Nao       Y27                                 Tails
# 584   Vikramaditya       Y27                                 Heads
# 770            Ady       Y27                                 Heads
# 861            Joy       Y27                                 Tails
# 940           Tian       Y27                                 Heads
# 956          Kenny       Y27                                 Heads
# 341           Ryan       Y27                                 Tails
# 453        Prateek       Y27                                 Heads
# 527         Payton       Y27                                 Tails
# 557          Berra       Y27                                 Heads
# 615           Alex       Y27                                 Heads
# 973          David       Y27                                 Heads
# 219          Darsh       Y27                                 Tails
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 485                                           Chocolate
# 361                                           Chocolate
# 1156                                          Chocolate
# 30                                            Chocolate
# 632                                             Vanilla
# 821                                           Chocolate
# 1096                                          Chocolate
# 193                                           Chocolate
# 584                                           Chocolate
# 770                                             Vanilla
# 861                                           Chocolate
# 940                                           Chocolate
# 956                                           Chocolate
# 341                                             Vanilla
# 453                                             Vanilla
# 527                                           Chocolate
# 557                                           Chocolate
# 615                                           Chocolate
# 973                                           Chocolate
# 219                                             Vanilla
#
#      Do you like morning or night? Is your favorite number even or odd?  \
# 485                        Morning                                 Even
# 361                        Morning                                  Odd
# 1156                         Night                                 Even
# 30                         Morning                                  Odd
# 632                        Morning                                 Even
# 821                        Morning                                  Odd
# 1096                         Night                                 Even
# 193                          Night                                 Even
# 584                          Night                                  Odd
# 770                        Morning                                 Even
# 861                          Night                                 Even
# 940                        Morning                                  Odd
# 956                        Morning                                 Even
# 341                          Night                                 Even
# 453                          Night                                  Odd
# 527                          Night                                  Odd
# 557                          Night                                 Even
# 615                          Night                                 Even
# 973                          Night                                 Even
# 219                          Night                                  Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 485                 Yes                          Winter
# 361                 Yes                          Winter
# 1156                Yes                          Winter
# 30                  Yes                          Summer
# 632                 Yes                          Winter
# 821                  No                          Winter
# 1096                Yes                          Winter
# 193                 Yes                          Winter
# 584                  No                          Summer
# 770                 Yes                          Summer
# 861                  No                          Winter
# 940                  No                          Summer
# 956                  No                          Summer
# 341                  No                          Summer
# 453                  No                          Winter
# 527                 Yes                          Summer
# 557                  No                          Summer
# 615                  No                          Summer
# 973                  No                          Summer
# 219                  No                          Summer
#
#      Are you in the Gies College of Business?  \
# 485                               Not in Gies
# 361                               Not in Gies
# 1156              In Gies College of Business
# 30                In Gies College of Business
# 632                               Not in Gies
# 821                               Not in Gies
# 1096                              Not in Gies
# 193                               Not in Gies
# 584                               Not in Gies
# 770               In Gies College of Business
# 861               In Gies College of Business
# 940                               Not in Gies
# 956                               Not in Gies
# 341                               Not in Gies
# 453                               Not in Gies
# 527                               Not in Gies
# 557                               Not in Gies
# 615                               Not in Gies
# 973               In Gies College of Business
# 219                               Not in Gies
#
#      Do you prefer Movies or TV shows?  ... What is your favorite color?  \
# 485                           TV Shows  ...                         gray
# 361                           TV Shows  ...                       purple
# 1156                          TV Shows  ...                         blue
# 30                            TV Shows  ...                       Purple
# 632                           TV Shows  ...                         blue
# 821                           TV Shows  ...                         Blue
# 1096                            Movies  ...                         pink
# 193                             Movies  ...                         Pink
# 584                           TV Shows  ...                        Green
# 770                           TV Shows  ...                         Blue
# 861                             Movies  ...                         blue
# 940                             Movies  ...                         Blue
# 956                             Movies  ...                          Red
# 341                           TV Shows  ...                        Green
# 453                             Movies  ...                        black
# 527                           TV Shows  ...                         Blue
# 557                           TV Shows  ...                         Blue
# 615                           TV Shows  ...                         Blue
# 973                             Movies  ...                        Green
# 219                             Movies  ...                         Blue
#
#      Favorite way to spend your free time?  \
# 485                       play mobile game
# 361                                rotting
# 1156                          Watch movie
# 30                                Shopping
# 632                                    gym
# 821                            Working out
# 1096                          With friends
# 193               hanging out with friends
# 584                                Gooning
# 770               hanging out with friends
# 861                           stay at home
# 940                      Playing basketall
# 956                          Gym or soccer
# 341                             Basketball
# 453                            Video Games
# 527                               Sleeping
# 557                           With friends
# 615                           With Friends
# 973                                    gym
# 219                  Scroll through Tiktok
#
#      What genre of music do you like the most?  \
# 485                                       Jazz
# 361                                       kpop
# 1156                                      pop
# 30                                         Pop
# 632                                        pop
# 821                                  Indie Pop
# 1096                                   hip hop
# 193                                        rap
# 584                                        R&B
# 770                                    Country
# 861                              popular music
# 940                                        Pop
# 956                                        Rap
# 341                                        Rap
# 453                                        Pop
# 527                               Alternative
# 557                                      Indie
# 615                                  Pop Music
# 973                                     polish
# 219                                        Rap
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 485                                               Panda
# 361                                                 cat
# 1156                                                dog
# 30                                                  Dog
# 632                                                 cat
# 821                                                Lion
# 1096                                            Cheetah
# 193                                            Meerkat
# 584                                                Lion
# 770                                               otter
# 861                                                 dog
# 940                                           Panda/yes
# 956                                                 Dog
# 341                                               Lion
# 453                                                 Dog
# 527                                             Peacock
# 557                                           Red Panda
# 615                                             Penguin
# 973                                           squierrel
# 219                                                 Dog
#
#      What do you think is the hardest major at UIUC?  \
# 485                                          Math+CS
# 361                                               CS
# 1156                                     engineering
# 30                                  Computer Science
# 632                                         comp eng
# 821                                      Engineering
# 1096                                             ECE
# 193                                 Computer Science
# 584                                        Sociology
# 770                                        chemistry
# 861                                               cs
# 940                                 Computer Science
# 956                                      Grainger CS
# 341                                         Business
# 453                           Aerospace Engineeering
# 527                                     Engineering
# 557                                 Computer Science
# 615                           Electrical Engineering
# 973                                               cs
# 219                           Electrical engineering
#
#      Who is your favorite music artist?  \
# 485                         My roommate
# 361                               ARTMS
# 1156                             laufey
# 30                          Noah Kahan
# 632                                 idk
# 821                                 TTC
# 1096                         Noah Kahan
# 193                    Childish Gambino
# 584                          Beabadobee
# 770                        Old Dominion
# 861                        Taylor Swift
# 940                            Jay Chou
# 956                          The Weeknd
# 341                               Drake
# 453                               Drake
# 527                 Tyler, the Creator
# 557                        Dominic Fike
# 615                            Jay Chou
# 973                               drake
# 219                               Drake
#
#      What's your favorite social media app?  \
# 485                                  WeChat
# 361                                 twitter
# 1156                              instagram
# 30                                   TikTok
# 632                               instagram
# 821                                  Tiktok
# 1096                              instagram
# 193                                  TikTok
# 584                                  Tiktok
# 770                                snapchat
# 861                                red note
# 940                                  Tiktok
# 956                                  Tiktok
# 341                               Instagram
# 453                               instagram
# 527                                  TikTok
# 557                                  TikTok
# 615                               Instagram
# 973                                snapchat
# 219                                  Tiktok
#
#      What is your favorite game to play (either video game or IRL)?  \
# 485                                       Honor of King
# 361                                              skyrim
# 1156                                           nonogram
# 30                                                 Clue
# 632                                                csgo
# 821                                               Poker
# 1096                                          minecraft
# 193                                  stress (card game)
# 584                                              Soccer
# 770                                         pickleball
# 861                                   Teamfight Tactics
# 940                                                 CS2
# 956                                  Soccer or Football
# 341                                            Fortnite
# 453                                             Cricket
# 527                                            Fortnite
# 557                                              Roblox
# 615                                    Football Manager
# 973                                        clash royale
# 219                                        Clash Royale
#
#      Where is your dream vacation spot? Similarity Score
# 485                         New zealand               17
# 361                         south korea               14
# 1156                              tokyo               12
# 30                              Croatia               11
# 632                              greece               11
# 821                              Hawaii               11
# 1096                             Europe               11
# 193                            Shang hi               10
# 584                              Cancun               10
# 770                              Hawaii               10
# 861                               Japan               10
# 940                               Beach               10
# 956                             Bahamas               10
# 341                               Japan                9
# 453                         Switzerland                9
# 527                              Canada                9
# 557                      Southern Italy                9
# 615                             Beaches                9
# 973                              hawaii                9
# 219                              Monaco                8
#
# [20 rows x 161 columns]

# %% [markdown]
# #### **➡️ Once you have that person, follow your TAs directions!<br> ➡️ They will tell you when to complete the rest of Puzzle 3.3**<br>
#
# Help them get up to this point in the lab and let them find their DISCOVERY twin!  *(Are you twins of each other?)*
#
# ➡️ Once you are **BOTH** to this section, introduce yourself and your DISCOVERY lab section "twin" to your lab TA. <br>
# ➡️ Make sure you know what your "Similarity Score" to your twin is! <br>
# ➡️ If you do this introduction to your TA **in-person during your lab section, you will earn +1 EC**! :)
#
# Note that there may be ties in `Similarity Score` due to the usage of only parts of the dataset. If you're curious, you can go back and **add more questions** to your `questions` list and `similarity(row)` function, rerunning the code to have more evaluative similarity scores.

# %% [markdown]
# ### Puzzle 3.4: The Course Staff
# A lot of wonderful course staff work together to bring you all the content for Data Science DISCOVERY.
#
# The course staff of 107 consists of the **Professors, TAs, and CAs**. As you saw in the previous parts, they've all completed the Hello Survey too!
#
# Their response under the `Name` column is standardized and follows these formats:
# - `Prof. [Name]`,
# - `TA [Name]`, or
# - `CA [Name]`
#
# The `contains` function will come in handy for us once again, because we can see if `"CA "`, `"TA "`, or `"Prof. "` is in the **names** of any rows in our DataFrame.
#
# Using the `contains` function, create a **new DataFrame** with just the course staff: `df_staff`, and display the dataframe.
#
# Read the following guide on **using `contains` to select all rows based on String contents**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-string-contains/
#
# *Note that we have to cast our `Name` column of `df` to a **string** by using `.str`.

# %%
# IMPORTANT: Make sure you include a whitespace in 'CA ' and 'TA ' so that people with those
# #          letters in their name aren't included.  Whitespace matters! :)

df_staff = df[df["Name"].astype(str).str.contains("Prof",na=False)|df["Name"].astype(str).str.contains("CA",na=False)|df["Name"].astype(str).str.contains("TA",na=False)]

df_staff
# Out:
#              Name              Lab When flipping a coin, heads or tails?  \
# 0      Prof. Wade              AL1                                 Heads
# 1     Prof. Karle              AL1                                 Heads
# 120      TA Tyler         Y06, Y10                                 Tails
# 220    CA Lyndsey         Y06, Y25                                 Heads
# 269        CA Ona         Y20, Y23                                 Heads
# ...           ...              ...                                   ...
# 1142   TA Jackson          Y29 Y36                                 Heads
# 1164   CA Jaythan         Y11, Y26                                 Heads
# 1176      CA Lara    Y24, Y33, Y40                                 Heads
# 1197      CA Emma              Y20                                 Tails
# 1198      CA Soph  Y01 Y14 Y15 Y18                                 Heads
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 1                                             Chocolate
# 120                                           Chocolate
# 220                                           Chocolate
# 269                                             Vanilla
# ...                                                 ...
# 1142                                            Vanilla
# 1164                                            Vanilla
# 1176                                          Chocolate
# 1197                                          Chocolate
# 1198                                            Vanilla
#
#      Do you like morning or night? Is your favorite number even or odd?  \
# 0                            Night                                  Odd
# 1                            Night                                 Even
# 120                          Night                                 Even
# 220                          Night                                  Odd
# 269                        Morning                                  Odd
# ...                            ...                                  ...
# 1142                         Night                                 Even
# 1164                         Night                                  Odd
# 1176                         Night                                 Even
# 1197                         Night                                  Odd
# 1198                         Night                                  Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                   Yes                          Winter
# 1                   Yes                          Summer
# 120                  No                          Winter
# 220                 Yes                          Summer
# 269                  No                          Summer
# ...                 ...                             ...
# 1142                Yes                          Summer
# 1164                Yes                          Winter
# 1176                 No                          Winter
# 1197                 No                          Summer
# 1198                Yes                          Winter
#
#      Are you in the Gies College of Business?  \
# 0                                 Not in Gies
# 1                                 Not in Gies
# 120                               Not in Gies
# 220                               Not in Gies
# 269                               Not in Gies
# ...                                       ...
# 1142                              Not in Gies
# 1164              In Gies College of Business
# 1176                              Not in Gies
# 1197                              Not in Gies
# 1198                              Not in Gies
#
#      Do you prefer Movies or TV shows?  ... What is your favorite color?  \
# 0                             TV Shows  ...                       Purple
# 1                               Movies  ...                         pink
# 120                           TV Shows  ...                       Orange
# 220                             Movies  ...                          Red
# 269                           TV Shows  ...                         Blue
# ...                                ...  ...                          ...
# 1142                          TV Shows  ...                          Red
# 1164                            Movies  ...                        Black
# 1176                            Movies  ...                  Light teal
# 1197                            Movies  ...                        Green
# 1198                          TV Shows  ...                          Red
#
#      Favorite way to spend your free time?  \
# 0                              Nerding Out
# 1                           with people!!!
# 120                       Playing Terraria
# 220                           With my dogs
# 269                                 TikTok
# ...                                    ...
# 1142                              Research
# 1164                  Hanging with Friends
# 1176                               Reading
# 1197                            Crocheting
# 1198                              Relaxing
#
#      What genre of music do you like the most?  \
# 0                                      Pop EDM
# 1                                          pop
# 120                                   Pop rock
# 220                                        Pop
# 269                                       Rock
# ...                                        ...
# 1142                                     Metal
# 1164                          Mexican Regional
# 1176                                  Shoegaze
# 1197                                       Pop
# 1198                                  Hyperpop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 Eagle
# 1                                                 sloth
# 120                                         Tardigrade
# 220                                                Deer
# 269                                                 Cat
# ...                                                 ...
# 1142                                            Penguin
# 1164                                            Penguin
# 1176                                             Mayfly
# 1197                                               Frog
# 1198                                             Rabbit
#
#      What do you think is the hardest major at UIUC?  \
# 0                                            Physics
# 1                                   computer science
# 120                            Chemical Engineering
# 220                             Computer engineering
# 269                                      Engineering
# ...                                              ...
# 1142                                             Art
# 1164                                  Bioengineering
# 1176                                         Physics
# 1197                                Computer Science
# 1198                          Aerospace Engineering
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 1                          Taylor Swift
# 120                          Billy Joel
# 220                       Gracie Abrams
# 269                              Hozier
# ...                                 ...
# 1142                       Les Claypool
# 1164                         Peso Pluma
# 1176                             Marina
# 1197                          Lady Gaga
# 1198                     Ayesha Erotica
#
#      What's your favorite social media app?  \
# 0                                   YouTube
# 1                                 instagram
# 120                                  Reddit
# 220                               Instagram
# 269                                  TikTok
# ...                                     ...
# 1142                                 Reddit
# 1164                              Instagram
# 1176                                 Reddit
# 1197                                 TikTok
# 1198                              Pinterest
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                              Factorio
# 1                                                 cards
# 120                                            Terraria
# 220                                             Jackbox
# 269                                                Clue
# ...                                                 ...
# 1142                                     Sea of Thieves
# 1164                                      Marvel Rivals
# 1176                                   Minds Beneath Us
# 1197                                          Minecraft
# 1198                                            Twister
#
#      Where is your dream vacation spot? Similarity Score
# 0                        Mountain Cabin                9
# 1                              Maldives                9
# 120                                 NaN                8
# 220                               Italy                9
# 269                             Iceland                9
# ...                                 ...              ...
# 1142                              Italy                8
# 1164                              Paris                7
# 1176                              Japan                9
# 1197                              Italy                8
# 1198                        Mexico City                9
#
# [67 rows x 161 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 3.3 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df_staff' in vars()), "Your DataFrame of course staff should be named 'df_staff'."
assert(len(df_staff) == 67), "Check you've added all the course staff correctly."
assert(len(df_staff.columns.to_list()) == 161), "You should have all of the questions columns and the Similarity Score column in df_staff." 

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.5: Course Staff Twin!
#
# Now that we have the course staff responses in `df_staff`, find your course staff twin (the staff member who has the **highest Similarity Score** to you) and display it.

# %%
top_two_staff = df_staff.nlargest(2, "Similarity Score")
top_two_staff
# Out:
#             Name          Lab When flipping a coin, heads or tails?  \
# 1136  CA Bella B  Y05 Y16 Y32                                 Heads
# 1117     TA Erik     Y15, Y21                                 Heads
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1136                                          Chocolate
# 1117                                            Vanilla
#
#      Do you like morning or night? Is your favorite number even or odd?  \
# 1136                       Morning                                 Even
# 1117                       Morning                                 Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1136                Yes                          Summer
# 1117                Yes                          Summer
#
#      Are you in the Gies College of Business?  \
# 1136                              Not in Gies
# 1117                              Not in Gies
#
#      Do you prefer Movies or TV shows?  ... What is your favorite color?  \
# 1136                          TV Shows  ...                       purple
# 1117                          TV Shows  ...               blue (#1d4ed8)
#
#      Favorite way to spend your free time?  \
# 1136                                   run
# 1117                               Driving
#
#      What genre of music do you like the most?  \
# 1136                                       pop
# 1117                                 Indie pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1136                                          butterfly
# 1117                                                Dog
#
#      What do you think is the hardest major at UIUC?  \
# 1136                                           cheme
# 1117                                             ECE
#
#      Who is your favorite music artist?  \
# 1136                  sabrina carpenter
# 1117                              Keshi
#
#      What's your favorite social media app?  \
# 1136                                 tiktok
# 1117                              Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1136                                         orangatang
# 1117                                 Escape from Tarkov
#
#      Where is your dream vacation spot? Similarity Score
# 1136                              Italy               14
# 1117                        Switzerland               12
#
# [2 rows x 161 columns]

# %% [markdown]
# ### Analysis: Final Reflection
#
# **Question 1:** Is it possible that the person that you found as your STAT107 "twin" may not find you as their twin? Explain your answer.
#
# **Question 2:** Do you think the method we used to find similar people is effective? Explain why or why not and give at least one suggestion to improve it.

# %% [markdown]
# Q1:It's possible I think. This can happen because the method for finding similar people depends on the attributes or criteria used, and those criteria might not be symmetric.
# Q2:Yeah,it's effective! if the dataset is limited or if certain traits are weighted equally when they shouldn’t be.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
